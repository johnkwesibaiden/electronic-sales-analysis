# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
df = pd.read_csv('Electronic_sales_Sep2023-Sep2024.csv')

# %%
df
# Out:
#        Customer ID  Age  Gender Loyalty Member Product Type      SKU  Rating  \
# 0             1000   53    Male             No   Smartphone  SKU1004       2
# 1             1000   53    Male             No       Tablet  SKU1002       3
# 2             1002   41    Male             No       Laptop  SKU1005       3
# 3             1002   41    Male            Yes   Smartphone  SKU1004       2
# 4             1003   75    Male            Yes   Smartphone  SKU1001       5
# ...            ...  ...     ...            ...          ...      ...     ...
# 19995        19996   27  Female             No   Smartphone   SMP234       4
# 19996        19996   27  Female            Yes       Laptop   LTP123       4
# 19997        19996   27  Female             No   Headphones   HDP456       4
# 19998        19997   27    Male             No   Headphones   HDP456       1
# 19999        19998   27     NaN            Yes       Laptop   LTP123       4
#
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Loyalty Member', 'Product Type', 'SKU',
#        'Rating', 'Order Status', 'Payment Method', 'Total Price', 'Unit Price',
#        'Quantity', 'Purchase Date', 'Shipping Type', 'Add-ons Purchased',
#        'Add-on Total'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Customer ID            int64
# Age                    int64
# Gender                object
# Loyalty Member        object
# Product Type          object
# SKU                   object
# Rating                 int64
# Order Status          object
# Payment Method        object
# Total Price          float64
# Unit Price           float64
# Quantity               int64
# Purchase Date         object
# Shipping Type         object
# Add-ons Purchased     object
# Add-on Total         float64
# dtype: object

# %%
df.describe()
# Out:
#         Customer ID           Age        Rating   Total Price    Unit Price  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean   10483.526550     48.994100      3.093950   3180.133419    578.631867
# std     5631.732525     18.038745      1.223764   2544.978675    312.274076
# min     1000.000000     18.000000      1.000000     20.750000     20.750000
# 25%     5478.000000     33.000000      2.000000   1139.680000    361.180000
# 50%    10499.500000     49.000000      3.000000   2534.490000    463.960000
# 75%    15504.000000     65.000000      4.000000   4639.600000    791.190000
# max    19998.000000     80.000000      5.000000  11396.800000   1139.680000
#
#            Quantity  Add-on Total
# count  20000.000000  20000.000000
# mean       5.485550     62.244848
# std        2.870854     58.058431
# min        1.000000      0.000000
# 25%        3.000000      7.615000
# 50%        5.000000     51.700000
# 75%        8.000000     93.842500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer ID        20000 non-null  int64
#  1   Age                20000 non-null  int64
#  2   Gender             19999 non-null  object
#  3   Loyalty Member     20000 non-null  object
#  4   Product Type       20000 non-null  object
#  5   SKU                20000 non-null  object
#  6   Rating             20000 non-null  int64
#  7   Order Status       20000 non-null  object
#  8   Payment Method     20000 non-null  object
#  9   Total Price        20000 non-null  float64
#  10  Unit Price         20000 non-null  float64
#  11  Quantity           20000 non-null  int64
#  12  Purchase Date      20000 non-null  object
#  13  Shipping Type      20000 non-null  object
#  14  Add-ons Purchased  15132 non-null  object
#  15  Add-on Total       20000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID             0
# Age                     0
# Gender                  1
# Loyalty Member          0
# Product Type            0
# SKU                     0
# Rating                  0
# Order Status            0
# Payment Method          0
# Total Price             0
# Unit Price              0
# Quantity                0
# Purchase Date           0
# Shipping Type           0
# Add-ons Purchased    4868
# Add-on Total            0
# dtype: int64

# %%
df.head(5)
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0    Cancelled    Credit Card      5538.33      791.19         7
# 1    Completed         Paypal       741.09      247.03         3
# 2    Completed    Credit Card      1855.84      463.96         4
# 3    Completed           Cash      3164.76      791.19         4
# 4    Completed           Cash        41.50       20.75         2
#
#   Purchase Date Shipping Type              Add-ons Purchased  Add-on Total
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sort_values(by='Order Status')
# Out:
#        Customer ID  Age  Gender Loyalty Member Product Type      SKU  Rating  \
# 0             1000   53    Male             No   Smartphone  SKU1004       2
# 9859          9883   20    Male            Yes   Smartphone  SKU1001       5
# 9860          9884   31  Female            Yes   Smartphone  SKU1001       5
# 9863          9886   59    Male            Yes       Laptop  SKU1005       3
# 9867          9892   24  Female             No       Tablet  SKU1002       3
# ...            ...  ...     ...            ...          ...      ...     ...
# 10274        11226   75    Male             No       Laptop   LTP123       3
# 3181          3890   41    Male            Yes   Smartphone  SKU1004       2
# 10276        11228   48  Female             No       Laptop   LTP123       4
# 10265        11218   53    Male             No       Tablet   TBL345       4
# 19999        19998   27     NaN            Yes       Laptop   LTP123       4
#
# ...

# %%
df.sort_values(by='Order Status').count()
# Out:
# Customer ID          20000
# Age                  20000
# Gender               19999
# Loyalty Member       20000
# Product Type         20000
# SKU                  20000
# Rating               20000
# Order Status         20000
# Payment Method       20000
# Total Price          20000
# Unit Price           20000
# Quantity             20000
# Purchase Date        20000
# Shipping Type        20000
# Add-ons Purchased    15132
# Add-on Total         20000
# dtype: int64

# %%
df.select_dtypes(include='object')
# Out:
#        Gender Loyalty Member Product Type      SKU Order Status  \
# 0        Male             No   Smartphone  SKU1004    Cancelled
# 1        Male             No       Tablet  SKU1002    Completed
# 2        Male             No       Laptop  SKU1005    Completed
# 3        Male            Yes   Smartphone  SKU1004    Completed
# 4        Male            Yes   Smartphone  SKU1001    Completed
# ...       ...            ...          ...      ...          ...
# 19995  Female             No   Smartphone   SMP234    Completed
# 19996  Female            Yes       Laptop   LTP123    Cancelled
# 19997  Female             No   Headphones   HDP456    Completed
# 19998    Male             No   Headphones   HDP456    Cancelled
# 19999     NaN            Yes       Laptop   LTP123    Completed
#
#       Payment Method Purchase Date Shipping Type  \
# 0        Credit Card    2024-03-20      Standard
# 1             Paypal    2024-04-20     Overnight
# ...

# %%
df['Add-ons Purchased'].value_counts()
# Out:
# Add-ons Purchased
# Extended Warranty                                  1701
# Accessory                                          1680
# Impulse Item                                       1645
# Extended Warranty,Impulse Item                      311
# Accessory,Impulse Item                              307
#                                                    ...
# Accessory, Extended Warranty, Accessory              80
# Accessory,Extended Warranty,Extended Warranty        78
# Extended Warranty, Extended Warranty, Accessory      76
# Accessory,Impulse Item,Impulse Item                  71
# Impulse Item,Extended Warranty,Accessory             68
# Name: count, Length: 75, dtype: int64

# %%
df['Add-ons Purchased'].count()
# Out:
# 15132

# %%
df['Add-ons Purchased'].nunique()
# Out:
# 75

# %%
df['Product Type'].value_counts()
# Out:
# Product Type
# Smartphone    5978
# Tablet        4104
# Laptop        3973
# Smartwatch    3934
# Headphones    2011
# Name: count, dtype: int64

# %%
ax = df['Product Type'].value_counts().plot(kind='bar', title='Product Order')

ax.set_xlabel('Product Type')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Order Status'].value_counts()
# Out:
# Order Status
# Completed    13432
# Cancelled     6568
# Name: count, dtype: int64

# %%
ax = df['Order Status'].value_counts().plot(kind='pie', title = 'Customer Order')

ax.set_xlabel ('Order Status')
ax.set_ylabel ('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card      5868
# Bank Transfer    3371
# PayPal           3284
# Paypal           2514
# Cash             2492
# Debit Card       2471
# Name: count, dtype: int64

# %%
ax = df['Payment Method'].value_counts().plot(kind='bar', title= 'Customer Preferred Payment Method')

ax.set_xlabel ('Payment Method')
ax.set_ylabel ('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Shipping Type'].value_counts()
# Out:
# Shipping Type
# Standard     6725
# Express      3366
# Overnight    3357
# Same Day     3280
# Expedited    3272
# Name: count, dtype: int64

# %%
ax = df['Shipping Type'].value_counts().plot(kind = 'bar', title = 'Customer preferred shipping type')
ax.set_xlabel('Shipping Type')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 3    7963
# 2    3972
# 5    3969
# 1    2061
# 4    2035
# Name: count, dtype: int64

# %%
ax=df['Rating'].value_counts().plot(kind='bar', title ='Customer rating')
ax.set_xlabel ('Rating')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Age'].value_counts()
# Out:
# Age
# 40    366
# 61    365
# 71    363
# 50    361
# 28    352
#      ...
# 51    286
# 76    284
# 34    277
# 46    266
# 20    262
# Name: count, Length: 63, dtype: int64

# %%
df['Customer ID'].value_counts()
# Out:
# Customer ID
# 18304    8
# 16357    7
# 12276    6
# 14497    6
# 7070     6
#         ..
# 12348    1
# 12345    1
# 12342    1
# 4970     1
# 19998    1
# Name: count, Length: 12136, dtype: int64

# %%
ax = df['Customer ID'].value_counts().head(5).plot(kind='bar', title = 'Top 5 Customers')
ax.set_xlabel('Customer ID')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df.head(5)
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0    Cancelled    Credit Card      5538.33      791.19         7
# 1    Completed         Paypal       741.09      247.03         3
# 2    Completed    Credit Card      1855.84      463.96         4
# 3    Completed           Cash      3164.76      791.19         4
# 4    Completed           Cash        41.50       20.75         2
#
#   Purchase Date Shipping Type              Add-ons Purchased  Add-on Total
# ...

# %%
df['Loyalty Member'].value_counts()
# Out:
# Loyalty Member
# No     15657
# Yes     4343
# Name: count, dtype: int64

# %%
ax=df['Loyalty Member'].value_counts().plot(kind='bar', title= 'Purchase by Loyalty member')
ax.set_xlabel ('Loyalty member')
ax.set_ylabel ('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      10164
# Female     9835
# Name: count, dtype: int64

# %%
sns.scatterplot(x=df['Add-ons Purchased'].value_counts(), y=df['Quantity'],)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df['Add-ons Purchased'].count(), y=df['Product Type'])
# Out:
# <Axes: ylabel='Product Type'>

# %%
sns.scatterplot(x=df['Quantity'], y=df['Add-ons Purchased'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Add-ons Purchased'>

# %%
sns.barplot(x=df['Quantity'], y=df['Add-ons Purchased'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Add-ons Purchased'>

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Loyalty Member', 'Product Type', 'SKU',
#        'Rating', 'Order Status', 'Payment Method', 'Total Price', 'Unit Price',
#        'Quantity', 'Purchase Date', 'Shipping Type', 'Add-ons Purchased',
#        'Add-on Total'],
#       dtype='object')

# %%
df3 = df.drop([
        'Gender', 'Loyalty Member', 'Product Type', 'SKU',
       'Rating', 'Order Status', 'Payment Method',  
        'Purchase Date', 'Shipping Type', 'Add-ons Purchased',
       'Add-on Total'],axis=1)

# %%
df3
# Out:
#        Customer ID  Age  Total Price  Unit Price  Quantity
# 0             1000   53      5538.33      791.19         7
# 1             1000   53       741.09      247.03         3
# 2             1002   41      1855.84      463.96         4
# 3             1002   41      3164.76      791.19         4
# 4             1003   75        41.50       20.75         2
# ...            ...  ...          ...         ...       ...
# 19995        19996   27      6838.08     1139.68         6
# 19996        19996   27      2697.28      674.32         4
# 19997        19996   27      1805.90      361.18         5
# 19998        19997   27      2528.26      361.18         7
# 19999        19998   27       674.32      674.32         1
#
# [20000 rows x 5 columns]

# %%
df3.corr()
# Out:
#              Customer ID       Age  Total Price  Unit Price  Quantity
# Customer ID     1.000000 -0.013297     0.203207    0.297445  0.010464
# Age            -0.013297  1.000000     0.003096   -0.004402  0.008555
# Total Price     0.203207  0.003096     1.000000    0.673951  0.653872
# Unit Price      0.297445 -0.004402     0.673951    1.000000  0.006715
# Quantity        0.010464  0.008555     0.653872    0.006715  1.000000

# %%
sns.heatmap(df3.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.groupby('Age').count()
# Out:
#      Customer ID  Gender  Loyalty Member  Product Type  SKU  Rating  \
# Age
# 18           301     301             301           301  301     301
# 19           317     317             317           317  317     317
# 20           262     262             262           262  262     262
# 21           332     332             332           332  332     332
# 22           302     302             302           302  302     302
# ..           ...     ...             ...           ...  ...     ...
# 76           284     284             284           284  284     284
# 77           312     312             312           312  312     312
# 78           321     321             321           321  321     321
# 79           310     310             310           310  310     310
# 80           289     289             289           289  289     289
#
#      Order Status  Payment Method  Total Price  Unit Price  Quantity  \
# Age
# ...

# %%
df.select_dtypes(include='integer')
# Out:
#        Customer ID  Age  Rating  Quantity
# 0             1000   53       2         7
# 1             1000   53       3         3
# 2             1002   41       3         4
# 3             1002   41       2         4
# 4             1003   75       5         2
# ...            ...  ...     ...       ...
# 19995        19996   27       4         6
# 19996        19996   27       4         4
# 19997        19996   27       4         5
# 19998        19997   27       1         7
# 19999        19998   27       4         1
#
# [20000 rows x 4 columns]

# %%
df4 = df.select_dtypes(include='integer')

# %%
df4.corr()
# Out:
#              Customer ID       Age    Rating  Quantity
# Customer ID     1.000000 -0.013297 -0.076836  0.010464
# Age            -0.013297  1.000000  0.002949  0.008555
# Rating         -0.076836  0.002949  1.000000 -0.008587
# Quantity        0.010464  0.008555 -0.008587  1.000000

# %%
sns.heatmap(df4.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.groupby('Total Price').count()
# Out:
#              Customer ID  Age  Gender  Loyalty Member  Product Type  SKU  \
# Total Price
# 20.75                220  220     220             220           220  220
# 41.50                202  202     202             202           202  202
# 62.25                215  215     215             215           215  215
# 83.00                194  194     194             194           194  194
# 103.75               188  188     188             188           188  188
# ...                  ...  ...     ...             ...           ...  ...
# 7977.76              210  210     210             210           210  210
# 8448.30              174  174     174             174           174  174
# 9117.44              204  204     204             204           204  204
# 10257.12             183  183     183             183           183  183
# 11396.80             200  200     200             200           200  200
#
#              Rating  Order Status  Payment Method  Unit Price  Quantity  \
# ...

# %%
df.head(5)
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0    Cancelled    Credit Card      5538.33      791.19         7
# 1    Completed         Paypal       741.09      247.03         3
# 2    Completed    Credit Card      1855.84      463.96         4
# 3    Completed           Cash      3164.76      791.19         4
# 4    Completed           Cash        41.50       20.75         2
#
#   Purchase Date Shipping Type              Add-ons Purchased  Add-on Total
# ...

# %%
sns.scatterplot(x ='Quantity',
           y ='Product Type',
            hue='Gender',
            data =df)
# Out:
# <Axes: xlabel='Quantity', ylabel='Product Type'>

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Loyalty Member', 'Product Type', 'SKU',
#        'Rating', 'Order Status', 'Payment Method', 'Total Price', 'Unit Price',
#        'Quantity', 'Purchase Date', 'Shipping Type', 'Add-ons Purchased',
#        'Add-on Total'],
#       dtype='object')

# %%
sns.pairplot(df, vars= ['Customer ID','Age','Rating','Total Price'],
            hue='Product Type')
plt.show()
